# %% [markdown]
# ### Assignment 2

# %% [markdown]
# Consider any image with size 1024x1024. Modify the image to the sizes 512x512, 256x256, 128x128, 64x64 and 32x32 using subsampling technique. Create the original image from all the above subsampled images using resampling technique.

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r'../Pics/nissangtr.jpg')

plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %%
hist_r= plt.hist(img[:,:,0].ravel(), bins=256, range=[0, 256], color='r', alpha=0.5)
plt.xlabel('Pixel intensity')
plt.ylabel('Count')
plt.show()

hist_g= plt.hist(img[:,:,1].ravel(), bins=256, range=[0, 256], color='g', alpha=0.5)
plt.xlabel('Pixel intensity')
plt.ylabel('Count')
plt.show()

hist_b = plt.hist(img[:,:,2].ravel(), bins=256, range=[0, 256], color='b', alpha=0.5)
plt.xlabel('Pixel intensity')
plt.ylabel('Count')
plt.show()
