# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Loading the image

# %%
img = cv2.imread(r'../Pics/camera.jpg')
plt.imshow(img)

# %% [markdown]
# Setting up parameters.

# %%
gamma = 0.1

# %%
gamma = 0.5

# %%
gamma = 1.2

# %%
gamma = 2.2

# %%
gamma_corrected = np.array(255*(img / 255) ** gamma, dtype = 'uint8')

plt.imshow(gamma_corrected)

# %%
cv2.imwrite(r'../Temp/gamma_transformed_'+str(gamma)+'.jpg', gamma_corrected)
