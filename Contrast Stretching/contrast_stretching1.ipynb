# %%
import cv2
import numpy as np

import matplotlib.pyplot as plt

# %%
# Read the image
IMAGE_PATH = r"../Pics/cells.jpg"
img = cv2.imread(IMAGE_PATH)

# %%
plt.imshow(img)

# %%
# Calculate the minimum and maximum pixel values
min_val, max_val, _, _ = cv2.minMaxLoc(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Calculate the minimum and maximum pixel values
# ----> 2 min_val, max_val, _, _ = cv2.minMaxLoc(img)
#
# error: OpenCV(4.7.0) /Users/opencv-cn/GHA-OCV-3/_work/opencv-python/opencv-python/opencv/modules/core/src/minmax.cpp:1504: error: (-215:Assertion failed) (cn == 1 && (_mask.empty() || _mask.type() == CV_8U)) || (cn > 1 && _mask.empty() && !minIdx && !maxIdx) in function 'minMaxIdx'

# %%
# Scale the pixel values to the full range [0, 255]
img = ((img - min_val) / (max_val - min_val)) * 255

# %%
# Convert the image to uint8
img = np.uint8(img)

# %%
# Display the image
cv2.imshow('Contrast Stretched Image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
